# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set()

# %%
mydata= pd.read_csv('Salary_Data.csv')

# %%
df= mydata.copy()

# %%
df.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
df.describe().T
# Out:
#                  count          mean           std      min       25%  \
# YearsExperience   30.0      5.313333      2.837888      1.1      3.20
# Salary            30.0  76003.000000  27414.429785  37731.0  56720.75
#
#                      50%        75%       max
# YearsExperience      4.7       7.70      10.5
# Salary           65237.0  100544.75  122391.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
plt.scatter(df.YearsExperience,df.Salary);

# %%
X= pd.DataFrame(df['YearsExperience'])

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.shape
# Out:
# (30, 1)

# %%
y=df.Salary

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Sklearn Starts

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([ 42673.40785466,  73344.35091946, 116877.30236629,  81259.4330007 ,
#         35747.71103357,  54546.03097652,  52567.26045621, 117866.68762644])

# %%
y_test
# Out:
# 3      43525.0
# 16     66029.0
# 26    116969.0
# 18     81363.0
# 1      46205.0
# 8      64445.0
# 6      60150.0
# 27    112635.0
# Name: Salary, dtype: float64

# %% [markdown]
# Visual Evaluation,Explained Variation, Unexplained Varaition, Total Variation, RSquared, Adj. RSqaured,MSE, MAE, RMSE, MAPE

# %%
plt.scatter(X_train,y_train);
plt.plot(X_train,model.predict(X_train),c='r');
plt.axhline(np.mean(y_train),c='g');
plt.xlabel('Years of Exp.')
plt.ylabel('Salary');

# %%
np.mean(y_train)
# Out:
# 76762.22727272728

# %%
plt.scatter(X_test,y_test);
plt.plot(X_test,model.predict(X_test),c='r');
plt.axhline(np.mean(y_test),c='g');
