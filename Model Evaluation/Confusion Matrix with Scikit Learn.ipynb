# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
mydata=pd.read_csv("customer_churn.csv")
mydata.head()
df=mydata.iloc[:,3:]
df.head()

y=df.iloc[:,-1]
y.head()

X=df.iloc[:,:- 1]
X.head()
#Basic Data Preprocessing
categorical_columns=X.describe(include='object').T.index.tolist()
X = pd.get_dummies(X,categorical_columns)
# Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33, random_state=100)
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

X_train=sc.fit_transform(X_train)
X_train=pd.DataFrame(X_train,columns=X_test.columns)

X_test=sc.transform(X_test)
X_test=pd.DataFrame(X_test,columns=X_train.columns)

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_train = model.predict(X_train)

# %%
accuracy_score(y_train,y_pred_train)
# Out:
# 0.8098507462686567

# %%
ymodel.predict(X_test,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 y_pred= model.predict(X_test,y_pred_train)
#
# TypeError: LinearClassifierMixin.predict() takes 2 positional arguments but 3 were given

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8115151515151515

# %%
(y_test==y_pred).mean()
# Out:
# 0.8115151515151515

# %%
y_test
# Out:
# 6252    0
# 4684    0
# 1731    0
# 4742    0
# 4521    0
#        ..
# 1744    0
# 9754    0
# 6094    0
# 8781    0
# 9401    1
# Name: Exited, Length: 3300, dtype: int64

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
  ConfusionMatrixDisplay.from_estimator(model,X_test,y_test,cmap='Blues',values_format='0.4g');

# %%
# This is old code will not run
plot_confusion_matrix(model,X_test,y_test,cmap='Greens',values_format='.4g')
