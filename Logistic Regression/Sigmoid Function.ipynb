# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
def my_sigmoid(x):
    return 1/(1+ np.exp(-x))

# %%
my_sigmoid(-10.67)
# Out:
# 2.3230993798759597e-05

# %%
my_sigmoid(0)
# Out:
# 0.5

# %%
my_sigmoid(2.3)
# Out:
# 0.9088770389851438

# %%
my_sigmoid(-18.9)
# Out:
# 6.192047644322584e-09

# %%
my_sigmoid(-1.2)
# Out:
# 0.23147521650098238

# %%
my_sigmoid(0)
# Out:
# 0.5

# %%
my_sigmoid(4749)
# Out:
# 1.0

# %%
a= np.linspace(-40,40,500000)

# %%
len(a)
# Out:
# 500000

# %%
plt.plot(a,my_sigmoid(a));

# %%
a
# Out:
# array([-40.       , -39.9839968, -39.9679936, ...,  39.9679936,
#         39.9839968,  40.       ])

# %%
plt.plot(a)

# %%
plt.plot(a,np.square(a))

# %%
plt.plot(a,my_sigmoid(a));

# %%
plt.plot(y,my_sigmoid(y))

# %%
my_sigmoid(0)

# %%
my_sigmoid(-4749)

# %%
y= np.linspace(-50,50,10000)

# %%
plt.plot(y);

# %%
plt.plot(y,my_sigmoid(y));

# %%
plt.plot(y,my_sigmoid(y),c='g')

# %%
#y= mx+c
y= np.linspace(-20,20,5000)

# %%
my_sigmoid(-1)

# %%
plt.plot(y,my_sigmoid(y),c='r');

# %%
my_sigmoid(-6.12244898)

# %%
x= np.linspace(-20,20,5000)

# %%
x

# %%
plt.plot(x);

# %%
y= my_sigmoid(x)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y,color='r');

# %%
my_sigmoid(0)

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
plot_confusion_matrix(y_test,y_pred)

# %%
plt.plot(y,my_sigmoid(y),c='r')

# %%
my_sigmoid(3.00601202)

# %%
x

# %%
len(x)

# %%
print(x)

# %%
plt.plot(x);

# %%
plt.plot(x,my_sigmoid(x),c='g')

# %%
plt.plot(x,my_sigmoid(x),c='r');

# %%
y= my_sigmoid(x)

# %%
plt.plot(x,y);

# %%
plt.plot(x,my_sigmoid(x),c='r');

# %%
x= np.linspace(-1000,1000,1000)

# %%
len(x)

# %%
x= np.linspace(-200,200,1000)

# %%
plt.plot(x,my_sigmoid(x),c='r');

# %%
x = np.linspace(-500,500,100)

# %%
len(x)

# %%
plt.plot(x,my_sigmoid(x));

# %%
my_sigmoid(-22.3) : always bounded between 0 and 1

# %%
x=np.linspace(-100.0, 100.0, num=50000)

# %%
x

# %%
len(x)

# %%
plt.plot(x,my_sigmoid(x),c='r');

# %%
plt.plot(x,my_sigmoid(x),c='r');
